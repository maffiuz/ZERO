# %%
from smain import main

main()
# Out:
# Using the values contained in userDefined/user_inputs.py ...
# c:\Riccardo\PoliTo\Progetto\ZERO\ReactorSimulator\tokamak\vector.py:319: RuntimeWarning: invalid value encountered in scalar power
#   tauE = LmodeConst * pow(self.isotopicMassNumber(), 0.5) * pow(self.ne * 1.e-20, 0.1) * pow(self.surfacePowerLoss(t) * 1.e-6, -0.5)
# c:\Riccardo\PoliTo\Progetto\ZERO\ReactorSimulator\tools\plotter.py:195: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# c:\Riccardo\PoliTo\Progetto\ZERO\ReactorSimulator\tools\plotter.py:192: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(i)

# %%
from two_points_model import main

main()
# Out:
# 1.25 3.045161290322581 59.3132692997753
# Using the values contained in userDefined/user_inputs.py ...
# {}
# c:\Riccardo\PoliTo\Progetto\ZERO\ReactorSimulator\two_points_model.py:65: RuntimeWarning: invalid value encountered in scalar power
#   T_t = pow(T_upstream**(7/2) - 7/2*q_par*connection_lentgh/KAPPA0E,2/7)
